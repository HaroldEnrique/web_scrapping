# %%
import requests
import pandas as pd
import numpy
from bs4 import BeautifulSoup
import re
import json
import copy

# %%
def post_request(category_id,size,url):
    data = {'categoryId':category_id,
            'customerGroupId':'0',
            'direction':'asc',
            'from':'0',
            'highlightEnabled':'false',
            'loadAggregations':'true',
            'order':'position',
            'searchTerm':'',
            'size': size,
            'store':'default'}
    
    r = requests.post(url,data = data)
    r_json = {}
    if r.status_code == 200:
        r_json = r.json()
    else:
        print('Response code is ', r.status_code)
    
    print('url post >',r.url)
    
    return r_json

# %%
def get_dict_groups(main_url):
    r = requests.get(main_url)
    sp = BeautifulSoup(r.text, 'lxml')
    categories = list(sp.nav.ul.children)
    categories.pop(0)
    categories.pop(-1)
    url_categories = [i.a.attrs['href'] for i in categories]
    dict_group = {}
    for url in url_categories:
        print(url)
        id_group,title = get_group_id(url)
        print(id_group,title)
        if id_group:
            dict_group[id_group] = {'name':title,'url':url}
    
    return dict_group

# %%
def get_group_id(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text,'lxml')
    print(soup)
    title = soup.title.text.strip()
    lista_script = str(soup.findAll('script')[41]).split('\n')
    group_id = ''
    for i in lista_script:
        if re.search('categoryId',i.strip()):
            group_id = i.strip()
    group_id = ''.join(filter(lambda i: i.isdigit(), group_id))
    return group_id,title

# %%
dict_group = get_dict_groups('https://www.tailoy.com.pe/')
dict_group
# Out:
# https://www.tailoy.com.pe/escolar.html
#  Escolar
# https://www.tailoy.com.pe/arte-y-dise-o.html
#  Arte y Diseño
# https://www.tailoy.com.pe/universitario.html
#  Universitario
# https://www.tailoy.com.pe/zona-de-lectura.html
#  Oficina
# https://www.tailoy.com.pe/cuidado-personal-y-limpieza.html
#  Cuidado Personal y Limpieza
# https://www.tailoy.com.pe/tecnologia.html
#  Tecnología
# https://www.tailoy.com.pe/zona-coleccionista.html
#  Zona Coleccionista
# https://www.tailoy.com.pe/outdoors-deporte.html
#  Outdoors & Deporte
# https://www.tailoy.com.pe/fisher-price.html
#  Fisher Price
# https://www.tailoy.com.pe/jugueteria.html
#  Juguetería
# https://www.tailoy.com.pe/abarrotes.html
#  Abarrotes
# {}

# %%
res = post_request('5',40,'https://www.tailoy.com.pe/elastic.php')
categories_by_group = res.get('aggregations').get('categories')
categories_by_group
# Out:
# url post > https://www.tailoy.com.pe/elastic.php
# {'5': {'label': 'Tecnología',
#   'level': '2',
#   'path': '1/2/5/',
#   'count': 486,
#   'id': '5',
#   'children': True},
#  '27': {'label': 'Fotografía',
#   'level': '3',
#   'path': '1/2/5/27/',
#   'parent': '5',
#   'count': 59,
#   'id': '27',
#   'children': True},
#  '32': {'label': 'Electrohogar',
#   'level': '3',
#   'path': '1/2/5/32/',
#   'parent': '5',
#   'count': 4,
#   'id': '32',
#   'children': True},
#  '33': {'label': 'Accesorios de Computo',
#   'level': '3',
#   'path': '1/2/5/33/',
#   'parent': '5',
#   'count': 133,
#   'id': '33',
#   'children': True},
#  '34': {'label': 'Otros',
#   'level': '3',
#   'path': '1/2/5/34/',
#   'parent': '5',
#   'count': 55,
#   'id': '34',
#   'children': True},
#  '28': {'label': 'Art Technology',
#   'level': '3',
#   'path': '1/2/5/28/',
#   'parent': '5',
#   'count': 19,
#   'id': '28',
#   'children': True},
#  '26': {'label': 'Audio',
#   'level': '3',
#   'path': '1/2/5/26/',
#   'parent': '5',
#   'count': 94,
#   'id': '26',
#   'children': True},
#  '31': {'label': 'Celulares',
#   'level': '3',
#   'path': '1/2/5/31/',
#   'parent': '5',
#   'count': 88,
#   'id': '31',
#   'children': True},
#  '25': {'label': 'Tv y Video',
#   'level': '3',
#   'path': '1/2/5/25/',
#   'parent': '5',
#   'count': 3,
#   'id': '25',
#   'children': True},
#  '30': {'label': 'Computo',
#   'level': '3',
#   'path': '1/2/5/30/',
#   'parent': '5',
#   'count': 155,
#   'id': '30',
#   'children': True},
#  '29': {'label': 'Mundo Gamer',
#   'level': '3',
#   'path': '1/2/5/29/',
#   'parent': '5',
#   'count': 46,
#   'id': '29',
#   'children': True},
#  '154': {'label': 'Sillas Gamer',
#   'level': '4',
#   'path': '1/2/5/29/154/',
#   'parent': '29',
#   'count': 2,
#   'id': '154'},
#  '179': {'label': 'Mousepads',
#   'level': '4',
#   'path': '1/2/5/33/179/',
#   'parent': '33',
#   'count': 5,
#   'id': '179'},
#  '149': {'label': 'Tabletas Gráficas',
#   'level': '4',
#   'path': '1/2/5/28/149/',
#   'parent': '28',
#   'count': 7,
#   'id': '149'},
#  '147': {'label': 'Accesorios de Arte',
#   'level': '4',
#   'path': '1/2/5/28/147/',
#   'parent': '28',
#   'count': 3,
#   'id': '147'},
#  '148': {'label': 'Monitores Interactivos',
#   'level': '4',
#   'path': '1/2/5/28/148/',
#   'parent': '28',
#   'count': 5,
#   'id': '148'},
#  '175': {'label': 'Kit Teclados',
#   'level': '4',
#   'path': '1/2/5/33/175/',
#   'parent': '33',
#   'count': 9,
#   'id': '175'},
#  '156': {'label': 'Componentes de PC',
#   'level': '4',
#   'path': '1/2/5/30/156/',
#   'parent': '30',
#   'count': 37,
#   'id': '156'},
#  '160': {'label': 'Monitores',
#   'level': '4',
#   'path': '1/2/5/30/160/',
#   'parent': '30',
#   'count': 6,
#   'id': '160'},
#  '136': {'label': 'Audífonos',
#   'level': '4',
#   'path': '1/2/5/26/136/',
#   'parent': '26',
#   'count': 83,
#   'id': '136'},
#  '163': {'label': 'Audífonos',
#   'level': '4',
#   'path': '1/2/5/31/163/',
#   'parent': '31',
#   'count': 83,
#   'id': '163'},
#  '134': {'label': 'Soundbar y Home Theater',
#   'level': '4',
#   'path': '1/2/5/25/134/',
#   'parent': '25',
#   'count': 2,
#   'id': '134'},
#  '157': {'label': 'Discos Duros y Memoria',
#   'level': '4',
#   'path': '1/2/5/30/157/',
#   'parent': '30',
#   'count': 25,
#   'id': '157'},
#  '178': {'label': 'Mouse',
#   'level': '4',
#   'path': '1/2/5/33/178/',
#   'parent': '33',
#   'count': 42,
#   'id': '178'},
#  '159': {'label': 'Láptops y Tablets',
#   'level': '4',
#   'path': '1/2/5/30/159/',
#   'parent': '30',
#   'count': 5,
#   'id': '159'},
#  '150': {'label': 'Accesorios Gamer',
#   'level': '4',
#   'path': '1/2/5/29/150/',
#   'parent': '29',
#   'count': 2,
#   'id': '150'},
#  '180': {'label': 'Otros accesorios',
#   'level': '4',
#   'path': '1/2/5/33/180/',
#   'parent': '33',
#   'count': 53,
#   'id': '180'},
#  '161': {'label': 'Tintas y Tóners',
#   'level': '4',
#   'path': '1/2/5/30/161/',
#   'parent': '30',
#   'count': 77,
#   'id': '161'},
#  '153': {'label': 'PC Gamer',
#   'level': '4',
#   'path': '1/2/5/29/153/',
#   'parent': '29',
#   'count': 6,
#   'id': '153'},
#  '604': {'label': 'Impresoras 3D',
#   'level': '4',
#   'path': '1/2/5/28/604/',
#   'parent': '28',
#   'count': 6,
#   'id': '604'},
#  '145': {'label': 'Drones',
#   'level': '4',
#   'path': '1/2/5/27/145/',
#   'parent': '27',
#   'count': 59,
#   'id': '145'},
#  '170': {'label': 'Electrodomésticos',
#   'level': '4',
#   'path': '1/2/5/32/170/',
#   'parent': '32',
#   'count': 4,
#   'id': '170'},
#  '183': {'label': 'Pilas, Baterías, Cargadores',
#   'level': '4',
#   'path': '1/2/5/34/183/',
#   'parent': '34',
#   'count': 14,
#   'id': '183'},
#  '158': {'label': 'Impresoras',
#   'level': '4',
#   'path': '1/2/5/30/158/',
#   'parent': '30',
#   'count': 5,
#   'id': '158'},
#  '152': {'label': 'Consolas',
#   'level': '4',
#   'path': '1/2/5/29/152/',
#   'parent': '29',
#   'count': 36,
#   'id': '152'},
#  '139': {'label': 'Parlantes y Micrófonos',
#   'level': '4',
#   'path': '1/2/5/26/139/',
#   'parent': '26',
#   'count': 11,
#   'id': '139'},
#  '144': {'label': 'Cámaras Profesionales',
#   'level': '4',
#   'path': '1/2/5/27/144/',
#   'parent': '27',
#   'count': 59,
#   'id': '144'},
#  '182': {'label': 'Calculadoras Y Otros',
#   'level': '4',
#   'path': '1/2/5/34/182/',
#   'parent': '34',
#   'count': 41,
#   'id': '182'},
#  '181': {'label': 'Teclados',
#   'level': '4',
#   'path': '1/2/5/33/181/',
#   'parent': '33',
#   'count': 5,
#   'id': '181'},
#  '135': {'label': 'Televisores',
#   'level': '4',
#   'path': '1/2/5/25/135/',
#   'parent': '25',
#   'count': 1,
#   'id': '135'},
#  '141': {'label': 'Cámaras Compactas',
#   'level': '4',
#   'path': '1/2/5/27/141/',
#   'parent': '27',
#   'count': 59,
#   'id': '141'},
#  '142': {'label': 'Cámaras de Video',
#   'level': '4',
#   'path': '1/2/5/27/142/',
#   'parent': '27',
#   'count': 59,
#   'id': '142'},
#  '143': {'label': 'Cámaras instantáneas',
#   'level': '4',
#   'path': '1/2/5/27/143/',
#   'parent': '27',
#   'count': 59,
#   'id': '143'},
#  '165': {'label': 'Cargadores y Cables',
#   'level': '4',
#   'path': '1/2/5/31/165/',
#   'parent': '31',
#   'count': 5,
#   'id': '165'},
#  '174': {'label': 'Discos duros y memorias',
#   'level': '4',
#   'path': '1/2/5/33/174/',
#   'parent': '33',
#   'count': 25,
#   'id': '174'}}

# %%
def get_all_levels(json_group):
    list_levels = []
    for key, value in json_group.items():
        level = int(value.get('level'))
        if level not in list_levels:
            list_levels.append(level)
    return list_levels

def get_cat_by_level(json_group, num_level):
    json_by_level = {}
    for key, value in json_group.items():
        level = int(value.get('level'))
        if level == num_level:
            json_by_level[key] = value

    return json_by_level

def order_dict(res_dict, level_dict):
    missed_dict = {}
    for key,value in level_dict.items():
        #print('>>>> 2 >>>> ',value)
        parent = value.get('parent','')
        if parent:
            group = res_dict.get(parent,'')
            #print(group)
            if group:
                if group.get('cats',''):
                    group['cats'].update({key:value})
                else:
                    group['cats'] = {key:value}
                #print(group)
            else:
                id_level_one = list(res_dict.keys())[0]
                cats = res_dict.get(id_level_one).get('cats','')
                #print('###### cats >>> ',cats)
                if cats:
                    if cats.get(parent,''):
                        if cats.get(parent).get('sub_cats',''):
                            cats.get(parent)['sub_cats'].update({key:value})
                        else:
                            cats.get(parent)['sub_cats'] = {key:value}
                    else:
                        missed_dict.update({key:value})
                else:
                    missed_dict.update({key:value})
                pass
    return res_dict, missed_dict


def get_group_cat_subcat(categories_by_group):
    global_dict = {}
    missed_dict = {}
    levels = get_all_levels(categories_by_group)
    levels.sort()
    #print(levels)
    if len(levels) > 3:
        print('################ ALERT, 1 LEVEL ADDED #################')
    #print(categories_by_group)
    for level in levels:
        level_dict = get_cat_by_level(categories_by_group,level)
        #print("level dict >>> ",level_dict)
        if global_dict:
            pass
            #print('b')
            initial_dict = copy.deepcopy(global_dict)
            global_dict,missed_dict = order_dict(initial_dict,level_dict)
            if missed_dict:
                print('###  ERROR:missed values   ###')
        else:
            #print('a')
            global_dict.update(level_dict)
            
    return global_dict

# %%
ordered_categories = get_group_cat_subcat(categories_by_group)
ordered_categories
# Out:
# {'5': {'label': 'Tecnología',
#   'level': '2',
#   'path': '1/2/5/',
#   'count': 486,
#   'id': '5',
#   'children': True,
#   'cats': {'27': {'label': 'Fotografía',
#     'level': '3',
#     'path': '1/2/5/27/',
#     'parent': '5',
#     'count': 59,
#     'id': '27',
#     'children': True,
#     'sub_cats': {'145': {'label': 'Drones',
#       'level': '4',
#       'path': '1/2/5/27/145/',
#       'parent': '27',
#       'count': 59,
#       'id': '145'},
#      '144': {'label': 'Cámaras Profesionales',
#       'level': '4',
#       'path': '1/2/5/27/144/',
#       'parent': '27',
#       'count': 59,
#       'id': '144'},
#      '141': {'label': 'Cámaras Compactas',
#       'level': '4',
#       'path': '1/2/5/27/141/',
#       'parent': '27',
#       'count': 59,
#       'id': '141'},
#      '142': {'label': 'Cámaras de Video',
#       'level': '4',
#       'path': '1/2/5/27/142/',
#       'parent': '27',
#       'count': 59,
#       'id': '142'},
#      '143': {'label': 'Cámaras instantáneas',
#       'level': '4',
#       'path': '1/2/5/27/143/',
#       'parent': '27',
#       'count': 59,
#       'id': '143'}}},
#    '32': {'label': 'Electrohogar',
#     'level': '3',
#     'path': '1/2/5/32/',
#     'parent': '5',
#     'count': 4,
#     'id': '32',
#     'children': True,
#     'sub_cats': {'170': {'label': 'Electrodomésticos',
#       'level': '4',
#       'path': '1/2/5/32/170/',
#       'parent': '32',
#       'count': 4,
#       'id': '170'}}},
#    '33': {'label': 'Accesorios de Computo',
#     'level': '3',
#     'path': '1/2/5/33/',
#     'parent': '5',
#     'count': 133,
#     'id': '33',
#     'children': True,
#     'sub_cats': {'179': {'label': 'Mousepads',
#       'level': '4',
#       'path': '1/2/5/33/179/',
#       'parent': '33',
#       'count': 5,
#       'id': '179'},
#      '175': {'label': 'Kit Teclados',
#       'level': '4',
#       'path': '1/2/5/33/175/',
#       'parent': '33',
#       'count': 9,
#       'id': '175'},
#      '178': {'label': 'Mouse',
#       'level': '4',
#       'path': '1/2/5/33/178/',
#       'parent': '33',
#       'count': 42,
#       'id': '178'},
#      '180': {'label': 'Otros accesorios',
#       'level': '4',
#       'path': '1/2/5/33/180/',
#       'parent': '33',
#       'count': 53,
#       'id': '180'},
#      '181': {'label': 'Teclados',
#       'level': '4',
#       'path': '1/2/5/33/181/',
#       'parent': '33',
#       'count': 5,
#       'id': '181'},
#      '174': {'label': 'Discos duros y memorias',
#       'level': '4',
#       'path': '1/2/5/33/174/',
#       'parent': '33',
#       'count': 25,
#       'id': '174'}}},
#    '34': {'label': 'Otros',
#     'level': '3',
#     'path': '1/2/5/34/',
#     'parent': '5',
#     'count': 55,
#     'id': '34',
#     'children': True,
#     'sub_cats': {'183': {'label': 'Pilas, Baterías, Cargadores',
#       'level': '4',
#       'path': '1/2/5/34/183/',
#       'parent': '34',
#       'count': 14,
#       'id': '183'},
#      '182': {'label': 'Calculadoras Y Otros',
#       'level': '4',
#       'path': '1/2/5/34/182/',
#       'parent': '34',
#       'count': 41,
#       'id': '182'}}},
#    '28': {'label': 'Art Technology',
#     'level': '3',
#     'path': '1/2/5/28/',
#     'parent': '5',
#     'count': 19,
#     'id': '28',
#     'children': True,
#     'sub_cats': {'149': {'label': 'Tabletas Gráficas',
#       'level': '4',
#       'path': '1/2/5/28/149/',
#       'parent': '28',
#       'count': 7,
#       'id': '149'},
#      '147': {'label': 'Accesorios de Arte',
#       'level': '4',
#       'path': '1/2/5/28/147/',
#       'parent': '28',
#       'count': 3,
#       'id': '147'},
#      '148': {'label': 'Monitores Interactivos',
#       'level': '4',
#       'path': '1/2/5/28/148/',
#       'parent': '28',
#       'count': 5,
#       'id': '148'},
#      '604': {'label': 'Impresoras 3D',
#       'level': '4',
#       'path': '1/2/5/28/604/',
#       'parent': '28',
#       'count': 6,
#       'id': '604'}}},
#    '26': {'label': 'Audio',
#     'level': '3',
#     'path': '1/2/5/26/',
#     'parent': '5',
#     'count': 94,
#     'id': '26',
#     'children': True,
#     'sub_cats': {'136': {'label': 'Audífonos',
#       'level': '4',
#       'path': '1/2/5/26/136/',
#       'parent': '26',
#       'count': 83,
#       'id': '136'},
#      '139': {'label': 'Parlantes y Micrófonos',
#       'level': '4',
#       'path': '1/2/5/26/139/',
#       'parent': '26',
#       'count': 11,
#       'id': '139'}}},
#    '31': {'label': 'Celulares',
#     'level': '3',
#     'path': '1/2/5/31/',
#     'parent': '5',
#     'count': 88,
#     'id': '31',
#     'children': True,
#     'sub_cats': {'163': {'label': 'Audífonos',
#       'level': '4',
#       'path': '1/2/5/31/163/',
#       'parent': '31',
#       'count': 83,
#       'id': '163'},
#      '165': {'label': 'Cargadores y Cables',
#       'level': '4',
#       'path': '1/2/5/31/165/',
#       'parent': '31',
#       'count': 5,
#       'id': '165'}}},
#    '25': {'label': 'Tv y Video',
#     'level': '3',
#     'path': '1/2/5/25/',
#     'parent': '5',
#     'count': 3,
#     'id': '25',
#     'children': True,
#     'sub_cats': {'134': {'label': 'Soundbar y Home Theater',
#       'level': '4',
#       'path': '1/2/5/25/134/',
#       'parent': '25',
#       'count': 2,
#       'id': '134'},
#      '135': {'label': 'Televisores',
#       'level': '4',
#       'path': '1/2/5/25/135/',
#       'parent': '25',
#       'count': 1,
#       'id': '135'}}},
#    '30': {'label': 'Computo',
#     'level': '3',
#     'path': '1/2/5/30/',
#     'parent': '5',
#     'count': 155,
#     'id': '30',
#     'children': True,
#     'sub_cats': {'156': {'label': 'Componentes de PC',
#       'level': '4',
#       'path': '1/2/5/30/156/',
#       'parent': '30',
#       'count': 37,
#       'id': '156'},
#      '160': {'label': 'Monitores',
#       'level': '4',
#       'path': '1/2/5/30/160/',
#       'parent': '30',
#       'count': 6,
#       'id': '160'},
#      '157': {'label': 'Discos Duros y Memoria',
#       'level': '4',
#       'path': '1/2/5/30/157/',
#       'parent': '30',
#       'count': 25,
#       'id': '157'},
#      '159': {'label': 'Láptops y Tablets',
#       'level': '4',
#       'path': '1/2/5/30/159/',
#       'parent': '30',
#       'count': 5,
#       'id': '159'},
#      '161': {'label': 'Tintas y Tóners',
#       'level': '4',
#       'path': '1/2/5/30/161/',
#       'parent': '30',
#       'count': 77,
#       'id': '161'},
#      '158': {'label': 'Impresoras',
#       'level': '4',
#       'path': '1/2/5/30/158/',
#       'parent': '30',
#       'count': 5,
#       'id': '158'}}},
#    '29': {'label': 'Mundo Gamer',
#     'level': '3',
#     'path': '1/2/5/29/',
#     'parent': '5',
#     'count': 46,
#     'id': '29',
#     'children': True,
#     'sub_cats': {'154': {'label': 'Sillas Gamer',
#       'level': '4',
#       'path': '1/2/5/29/154/',
#       'parent': '29',
#       'count': 2,
#       'id': '154'},
#      '150': {'label': 'Accesorios Gamer',
#       'level': '4',
#       'path': '1/2/5/29/150/',
#       'parent': '29',
#       'count': 2,
#       'id': '150'},
#      '153': {'label': 'PC Gamer',
#       'level': '4',
#       'path': '1/2/5/29/153/',
#       'parent': '29',
#       'count': 6,
#       'id': '153'},
#      '152': {'label': 'Consolas',
#       'level': '4',
#       'path': '1/2/5/29/152/',
#       'parent': '29',
#       'count': 36,
#       'id': '152'}}}}}}

# %% [markdown]
# ## Get products

# %%
def iterate_over_group(data_by_group):
    df_group_products = pd.DataFrame([])
    for key, value in data_by_group.items():
        
        name_group = value.get('label')
        id_group = value.get('id')
        print('group >',name_group,id_group)
        cats_dict = value.get('cats')
        for k,v in cats_dict.items():
            
            name_cat = v.get('label')
            id_cat = v.get('id')
            print('cats >',name_cat,id_cat)
            subcats_dict = v.get('sub_cats','')
            #size_subcat = len(list(subcats_dict.keys()))
            if subcats_dict:
                for x,y in subcats_dict.items():
                    
                    name_subcat = y.get('label')
                    id_subcat = y.get('id')
                    count_subcat = y.get('count')
                    print('subcats >',name_subcat,id_subcat,count_subcat)
                    
                    
                    lista_products = get_products(id_subcat)
                    df_subcat = pd.DataFrame(lista_products)

                    df_subcat.insert(loc=0, column='id_group', value=id_group)
                    df_subcat.insert(loc=1, column='name_group', value=name_group)
                    df_subcat.insert(loc=2, column='id_cat', value=id_cat)
                    df_subcat.insert(loc=3, column='name_cat', value=name_cat)
                    df_subcat.insert(loc=4, column='id_subcat', value=id_subcat)
                    df_subcat.insert(loc=5, column='name_subcat', value=name_subcat)
                    df_subcat.insert(loc=6, column='count_subcat', value=count_subcat)

                    df_group_products = df_group_products.append(df_subcat)

            else:
                name_subcat, id_subcat, count_subcat = '','',''
                lista_products_2 = get_products(id_cat)
                df_cat = pd.DataFrame(lista_products_2)

                df_cat.insert(loc=0, column='id_group', value=id_group)
                df_cat.insert(loc=1, column='name_group', value=name_group)
                df_cat.insert(loc=2, column='id_cat', value=id_cat)
                df_cat.insert(loc=3, column='name_cat', value=name_cat)
                df_cat.insert(loc=4, column='id_subcat', value=id_subcat)
                df_cat.insert(loc=5, column='name_subcat', value=name_subcat)
                df_cat.insert(loc=6, column='count_subcat', value=count_subcat)

                df_group_products = df_group_products.append(df_cat)

            #df_subcat.insert(loc=idx_subcat, column='id_branch', value=str(tp[0]))
    return df_group_products

# %%
def get_products(id_category):
    size_rows = 4000
    data_products = []
    diff = 0
    while diff == 0:
        res = post_request(id_category,size_rows,'https://www.tailoy.com.pe/elastic.php')
        total = int(res.get('amount').get('total'))
        diff = size_rows - total
        size_rows += 1000
        data_products = res.get('products')

    list_products = []
    info_product = {}
    for product in data_products:
        info_product['id_pro'] = product.get('id')
        info_product['name_pro'] = product.get('name')
        info_product['img_url'] = product.get('base_image')
        info_product['codeas_pro'] = product.get('tailoyetl_999_codeas')
        info_product['marca_pro'] = ', '.join(product.get('tailoyetl_999_marcav2'))
        info_product['description_pro'] = clean_description(product.get('description'))
        info_product['keys_pro'] = product.get('word_search_tailoy')
        info_product['discount_pro'] = product.get('discount','')
        info_product['price_pro'] = product.get('prices_0').get('price')
        info_product['final_price_pro'] = product.get('prices_0').get('final_price')
        info_product['minimal_price_pro'] = product.get('prices_0').get('minimal_price')
        info_product['mix_price_pro'] = product.get('prices_0').get('min_price')
        info_product['max_price_pro'] = product.get('prices_0').get('max_price')
        info_product['rating_pro'] = product.get('rating')
        info_product['review_pro'] = product.get('review_count')
        info_product['max_sale_qty_pro'] = product.get('max_sale_qty')
        info_product['min_sale_qty_pro'] = product.get('min_sale_qty')
        info_product['qty_increments_pro'] = product.get('qty_increments')
        info_product['url_pro'] = product.get('url')

        list_products.append(info_product)
        info_product = {}
        
    return list_products

# %%
def clean_description(text):
    so = BeautifulSoup(text,'html.parser')
    clean_txt = so.text.split('\n')[-1].strip()
    return clean_txt

# %%
iterate_over_group(ordered_categories)
# Out:
# group > Tecnología 5
# cats > Fotografía 27
# subcats > Drones 145 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras Profesionales 144 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras Compactas 141 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras de Video 142 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras instantáneas 143 59
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Electrohogar 32
# subcats > Electrodomésticos 170 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Accesorios de Computo 33
# subcats > Mousepads 179 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3e9f48ba3435> in <module>
# ----> 1 iterate_over_group(ordered_categories)
#
# <ipython-input-9-0478a3f49f82> in iterate_over_group(data_by_group)
#      23
#      24
# ---> 25                     lista_products = get_products(id_subcat)
#      26                     df_subcat = pd.DataFrame(lista_products)
#      27
#
# <ipython-input-10-8839e9313a0a> in get_products(id_category)
#       4     diff = 0
#       5     while diff == 0:
# ----> 6         res = post_request(id_category,size_rows,'https://www.tailoy.com.pe/elastic.php')
#       7         total = int(res.get('amount').get('total'))
#       8         diff = size_rows - total
#
# <ipython-input-2-2c60940fda96> in post_request(category_id, size, url)
#      11             'store':'default'}
#      12
# ---> 13     r = requests.post(url,data = data)
#      14     r_json = {}
#      15     if r.status_code == 200:
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     974         # Force connect early to allow us to validate the connection.
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#     978         if not conn.is_verified:
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\connection.py in connect(self)
#     306     def connect(self):
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#     310
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#     162
#
# d:\pyscripts\ws_anthony\env\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             if source_address:
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#      76
#
# KeyboardInterrupt:

# %% [markdown]
# ## Main

# %%
#ict_group = get_dict_groups('https://www.tailoy.com.pe/')

dict_group = {'9': {'name': 'Escolar', 'url': 'https://www.tailoy.com.pe/escolar.html'},
 '8': {'name': 'Arte y Diseño',
  'url': 'https://www.tailoy.com.pe/arte-y-dise-o.html'},
 '10': {'name': 'Universitario',
  'url': 'https://www.tailoy.com.pe/universitario.html'},
 '11': {'name': 'Oficina',
  'url': 'https://www.tailoy.com.pe/zona-de-lectura.html'},
 '621': {'name': 'Cuidado Personal y Limpieza',
  'url': 'https://www.tailoy.com.pe/cuidado-personal-y-limpieza.html'},
 '5': {'name': 'Tecnología',
  'url': 'https://www.tailoy.com.pe/tecnologia.html'},
 '6': {'name': 'Zona Coleccionista',
  'url': 'https://www.tailoy.com.pe/zona-coleccionista.html'},
 '7': {'name': 'Outdoors & Deporte',
  'url': 'https://www.tailoy.com.pe/outdoors-deporte.html'},
 '16': {'name': 'Fisher Price',
  'url': 'https://www.tailoy.com.pe/fisher-price.html'},
 '3': {'name': 'Juguetería',
  'url': 'https://www.tailoy.com.pe/jugueteria.html'},
 '639': {'name': 'Abarrotes',
  'url': 'https://www.tailoy.com.pe/abarrotes.html'}}

# %%
for k,v in dict_group.items():

    res = post_request(k,40,'https://www.tailoy.com.pe/elastic.php')
    categories_by_group = res.get('aggregations').get('categories')
    tree_by_group = get_group_cat_subcat(categories_by_group)
    print(tree_by_group)
    key_first = list(tree_by_group.keys())[0]
    print(key_first)
    name_file = key_first + '_' + str(tree_by_group.get(key_first).get('label')).lower().replace(" ",'') 

    df_group = iterate_over_group(tree_by_group)
    #print(df_group.head())
    df_group.to_csv(name_file+'_'+str(df_group.shape[0])+'.csv',index=False,header=True,encoding='utf-8')
# Out:
# url post > https://www.tailoy.com.pe/elastic.php
# {'9': {'label': 'Escolar', 'level': '2', 'path': '1/2/9/', 'count': 2829, 'id': '9', 'children': True, 'cats': {'49': {'label': 'Forros y Etiquetas', 'level': '3', 'path': '1/2/9/49/', 'parent': '9', 'count': 79, 'id': '49', 'children': True, 'sub_cats': {'281': {'label': 'Cintas Adhesivas', 'level': '4', 'path': '1/2/9/49/281/', 'parent': '49', 'count': 24, 'id': '281'}, '283': {'label': 'Forros', 'level': '4', 'path': '1/2/9/49/283/', 'parent': '49', 'count': 18, 'id': '283'}, '284': {'label': 'Stickers', 'level': '4', 'path': '1/2/9/49/284/', 'parent': '49', 'count': 5, 'id': '284'}, '282': {'label': 'Etiquetas', 'level': '4', 'path': '1/2/9/49/282/', 'parent': '49', 'count': 32, 'id': '282'}}}, '51': {'label': 'Archivo', 'level': '3', 'path': '1/2/9/51/', 'parent': '9', 'count': 233, 'id': '51', 'children': True, 'sub_cats': {'292': {'label': 'Pioners Escolares', 'level': '4', 'path': '1/2/9/51/292/', 'parent': '51', 'count': 78, 'id': '292'}, '290': {'label': 'Carpetas y Portatodos', 'level': '4', 'path': '1/2/9/51/290/', 'parent': '51', 'count': 23, 'id': '290'}, '291': {'label': 'Folders Escolares', 'level': '4', 'path': '1/2/9/51/291/', 'parent': '51', 'count': 154, 'id': '291'}}}, '53': {'label': 'Manualidades', 'level': '3', 'path': '1/2/9/53/', 'parent': '9', 'count': 608, 'id': '53', 'children': True, 'sub_cats': {'301': {'label': 'Juegos didácticos', 'level': '4', 'path': '1/2/9/53/301/', 'parent': '53', 'count': 44, 'id': '301'}, '308': {'label': 'Tijeras', 'level': '4', 'path': '1/2/9/53/308/', 'parent': '53', 'count': 58, 'id': '308'}, '299': {'label': 'Ceramica en frío', 'level': '4', 'path': '1/2/9/53/299/', 'parent': '53', 'count': 20, 'id': '299'}, '298': {'label': 'Blocks de manualidades', 'level': '4', 'path': '1/2/9/53/298/', 'parent': '53', 'count': 27, 'id': '298'}, '307': {'label': 'Rompecabezas didácticos', 'level': '4', 'path': '1/2/9/53/307/', 'parent': '53', 'count': 6, 'id': '307'}, '306': {'label': 'Plastilinas', 'level': '4', 'path': '1/2/9/53/306/', 'parent': '53', 'count': 43, 'id': '306'}, '304': {'label': 'Pasamanería y otros', 'level': '4', 'path': '1/2/9/53/304/', 'parent': '53', 'count': 77, 'id': '304'}, '305': {'label': 'Pinceles escolares', 'level': '4', 'path': '1/2/9/53/305/', 'parent': '53', 'count': 20, 'id': '305'}, '300': {'label': 'Cinta de agua', 'level': '4', 'path': '1/2/9/53/300/', 'parent': '53', 'count': 7, 'id': '300'}, '303': {'label': 'Papeles para manualidades', 'level': '4', 'path': '1/2/9/53/303/', 'parent': '53', 'count': 133, 'id': '303'}, '297': {'label': 'Accesorios Pintura', 'level': '4', 'path': '1/2/9/53/297/', 'parent': '53', 'count': 39, 'id': '297'}, '302': {'label': 'Microporoso y corospum', 'level': '4', 'path': '1/2/9/53/302/', 'parent': '53', 'count': 136, 'id': '302'}}}, '47': {'label': 'Papelería', 'level': '3', 'path': '1/2/9/47/', 'parent': '9', 'count': 312, 'id': '47', 'children': True, 'sub_cats': {'250': {'label': 'Papel Bond', 'level': '4', 'path': '1/2/9/47/250/', 'parent': '47', 'count': 25, 'id': '250'}, '254': {'label': 'Papel Fotocopia', 'level': '4', 'path': '1/2/9/47/254/', 'parent': '47', 'count': 16, 'id': '254'}, '255': {'label': 'Papel Fotográfico y otros', 'level': '4', 'path': '1/2/9/47/255/', 'parent': '47', 'count': 25, 'id': '255'}, '257': {'label': 'Papeles Adhesivos', 'level': '4', 'path': '1/2/9/47/257/', 'parent': '47', 'count': 4, 'id': '257'}, '259': {'label': 'Papeles para manualidades', 'level': '4', 'path': '1/2/9/47/259/', 'parent': '47', 'count': 133, 'id': '259'}, '248': {'label': 'Cartones', 'level': '4', 'path': '1/2/9/47/248/', 'parent': '47', 'count': 24, 'id': '248'}, '249': {'label': 'Cartulinas', 'level': '4', 'path': '1/2/9/47/249/', 'parent': '47', 'count': 90, 'id': '249'}, '256': {'label': 'Papel Periódico', 'level': '4', 'path': '1/2/9/47/256/', 'parent': '47', 'count': 1, 'id': '256'}, '258': {'label': 'Papeles Finos', 'level': '4', 'path': '1/2/9/47/258/', 'parent': '47', 'count': 1, 'id': '258'}, '260 ...
# 9
# group > Escolar 9
# cats > Forros y Etiquetas 49
# subcats > Cintas Adhesivas 281 24
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Forros 283 18
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Stickers 284 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Etiquetas 282 32
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Archivo 51
# subcats > Pioners Escolares 292 78
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Carpetas y Portatodos 290 23
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Folders Escolares 291 154
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Manualidades 53
# subcats > Juegos didácticos 301 44
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tijeras 308 58
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Ceramica en frío 299 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de manualidades 298 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Rompecabezas didácticos 307 6
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plastilinas 306 43
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pasamanería y otros 304 77
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pinceles escolares 305 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cinta de agua 300 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles para manualidades 303 133
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Accesorios Pintura 297 39
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Microporoso y corospum 302 136
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Papelería 47
# subcats > Papel Bond 250 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Fotocopia 254 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Fotográfico y otros 255 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles Adhesivos 257 4
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles para manualidades 259 133
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cartones 248 24
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cartulinas 249 90
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Periódico 256 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles Finos 258 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papelógrafos 260 4
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Celofán 251 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Útiles 48
# subcats > Tijeras 280 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones Idelebles 272 21
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Resaltadores 277 82
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Crayones y Óleos 265 32
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Témperas y acuarelas escolares 279 76
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Correctores 264 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Motas y Tizas 269 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Portaminas y minas 275 19
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Colores 262 80
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Compases 263 68
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Escuadras 266 69
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Reglas 276 68
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lápices 268 65
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tajadores 278 35
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Borradores 261 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lapiceros 267 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plastilinas 271 43
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pizarras 270 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones para papel 273 287
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones para pizarra 274 8
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Útiles para el Salón 55
# subcats > Motas y Tizas 318 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Engrapadores, sacagrapas y grapas 316 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Perforadores 321 44
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Notas adhesivas y banderitas 319 78
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Desinfectantes 315 91
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpiatipos 317 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cuadernos y Blocks 46
# subcats > Cuadernos Grapados A4 244 67
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos Anillados 242 29
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de Manualidades 241 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Sketchbooks 247 18
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de escritura y libretas 240 36
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos Grapados A5 245 3
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos Cosidos 243 11
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Libretas 246 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Textos 54
# subcats > Tablas 313 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Diccionarios 310 8
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Refuerzo en casa 312 40
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Textos Escolares 314 234
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plan Lector 311 9
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Biblias 309 2
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Mochilas, Cartucheras y Loncheras 50
# subcats > Tomatodos 289 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cartucheras 285 15
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tapers 288 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Maletas y mochilas 287 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Loncheras 286 2
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cintas y Pegamentos 52
# subcats > Otros Pegamentos 296 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cintas adhesivas y masking tape 293 68
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Gomas, siliconas y colas 294 56
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpiatipos 295 3
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'8': {'label': 'Arte y Diseño', 'level': '2', 'path': '1/2/8/', 'count': 1117, 'id': '8', 'children': True, 'cats': {'42': {'label': 'Manualidades', 'level': '3', 'path': '1/2/8/42/', 'parent': '8', 'count': 607, 'id': '42', 'children': True, 'sub_cats': {'225': {'label': 'Tijeras', 'level': '4', 'path': '1/2/8/42/225/', 'parent': '42', 'count': 58, 'id': '225'}, '214': {'label': 'Accesorios Pintura', 'level': '4', 'path': '1/2/8/42/214/', 'parent': '42', 'count': 39, 'id': '214'}, '218': {'label': 'Juegos Didácticos', 'level': '4', 'path': '1/2/8/42/218/', 'parent': '42', 'count': 43, 'id': '218'}, '216': {'label': 'Cerámica en frio', 'level': '4', 'path': '1/2/8/42/216/', 'parent': '42', 'count': 18, 'id': '216'}, '215': {'label': 'Blocks de manualidades', 'level': '4', 'path': '1/2/8/42/215/', 'parent': '42', 'count': 27, 'id': '215'}, '222': {'label': 'Pinceles Escolares', 'level': '4', 'path': '1/2/8/42/222/', 'parent': '42', 'count': 20, 'id': '222'}, '219': {'label': 'Microporoso y Corospum', 'level': '4', 'path': '1/2/8/42/219/', 'parent': '42', 'count': 136, 'id': '219'}, '223': {'label': 'Plastilinas', 'level': '4', 'path': '1/2/8/42/223/', 'parent': '42', 'count': 43, 'id': '223'}, '221': {'label': 'Pasamanería y Otros', 'level': '4', 'path': '1/2/8/42/221/', 'parent': '42', 'count': 77, 'id': '221'}, '220': {'label': 'Papeles de Manualidades', 'level': '4', 'path': '1/2/8/42/220/', 'parent': '42', 'count': 133, 'id': '220'}, '224': {'label': 'Rompecabezas Didácticos', 'level': '4', 'path': '1/2/8/42/224/', 'parent': '42', 'count': 6, 'id': '224'}, '217': {'label': 'Cinta de Agua', 'level': '4', 'path': '1/2/8/42/217/', 'parent': '42', 'count': 7, 'id': '217'}}}, '43': {'label': 'Dibujo', 'level': '3', 'path': '1/2/8/43/', 'parent': '8', 'count': 319, 'id': '43', 'children': True, 'sub_cats': {'226': {'label': 'Accesorios de Dibujo', 'level': '4', 'path': '1/2/8/43/226/', 'parent': '43', 'count': 32, 'id': '226'}, '230': {'label': 'Marcadores y estilógrafos', 'level': '4', 'path': '1/2/8/43/230/', 'parent': '43', 'count': 200, 'id': '230'}, '227': {'label': 'Blocks de Arte', 'level': '4', 'path': '1/2/8/43/227/', 'parent': '43', 'count': 9, 'id': '227'}, '229': {'label': 'Lápices de color, grafito y carboncillo', 'level': '4', 'path': '1/2/8/43/229/', 'parent': '43', 'count': 75, 'id': '229'}, '228': {'label': 'Cartulinas', 'level': '4', 'path': '1/2/8/43/228/', 'parent': '43', 'count': 9, 'id': '228'}}}, '44': {'label': 'Pintura', 'level': '3', 'path': '1/2/8/44/', 'parent': '8', 'count': 289, 'id': '44', 'children': True, 'sub_cats': {'235': {'label': 'Óleos', 'level': '4', 'path': '1/2/8/44/235/', 'parent': '44', 'count': 96, 'id': '235'}, '238': {'label': 'Témperas y acuarelas escolares', 'level': '4', 'path': '1/2/8/44/238/', 'parent': '44', 'count': 78, 'id': '238'}, '231': {'label': 'Acuarela y Acrílicos', 'level': '4', 'path': '1/2/8/44/231/', 'parent': '44', 'count': 75, 'id': '231'}, '232': {'label': 'Auxiliares', 'level': '4', 'path': '1/2/8/44/232/', 'parent': '44', 'count': 7, 'id': '232'}, '236': {'label': 'Pinceles', 'level': '4', 'path': '1/2/8/44/236/', 'parent': '44', 'count': 31, 'id': '236'}, '233': {'label': 'Caballetes y Cajas', 'level': '4', 'path': '1/2/8/44/233/', 'parent': '44', 'count': 12, 'id': '233'}, '234': {'label': 'Lienzos', 'level': '4', 'path': '1/2/8/44/234/', 'parent': '44', 'count': 12, 'id': '234'}, '636': {'label': 'Témperas y Tintas', 'level': '4', 'path': '1/2/8/44/636/', 'parent': '44', 'count': 16, 'id': '636'}, '237': {'label': 'Pinceles Escolares', 'level': '4', 'path': '1/2/8/44/237/', 'parent': '44', 'count': 20, 'id': '237'}}}, '45': {'label': 'Sets de Regalo', 'level': '3', 'path': '1/2/8/45/', 'parent': '8', 'count': 2, 'id': '45', 'children': True, 'sub_cats': {'239': {'label': 'Sets de Regalo', 'level': '4', 'path': '1/2/8/45/239/', 'parent': '45', 'count': 2, 'id': '239'}}}}}}
# 8
# group > Arte y Diseño 8
# cats > Manualidades 42
# subcats > Tijeras 225 58
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Accesorios Pintura 214 39
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juegos Didácticos 218 43
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cerámica en frio 216 18
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de manualidades 215 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pinceles Escolares 222 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Microporoso y Corospum 219 136
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plastilinas 223 43
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pasamanería y Otros 221 77
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles de Manualidades 220 133
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Rompecabezas Didácticos 224 6
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cinta de Agua 217 7
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Dibujo 43
# subcats > Accesorios de Dibujo 226 32
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Marcadores y estilógrafos 230 200
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de Arte 227 9
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lápices de color, grafito y carboncillo 229 75
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cartulinas 228 9
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Pintura 44
# subcats > Óleos 235 96
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Témperas y acuarelas escolares 238 78
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Acuarela y Acrílicos 231 75
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Auxiliares 232 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pinceles 236 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Caballetes y Cajas 233 12
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lienzos 234 12
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Témperas y Tintas 636 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pinceles Escolares 237 20
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Sets de Regalo 45
# subcats > Sets de Regalo 239 2
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'10': {'label': 'Universitario', 'level': '2', 'path': '1/2/10/', 'count': 1542, 'id': '10', 'children': True, 'cats': {'62': {'label': 'Otros', 'level': '3', 'path': '1/2/10/62/', 'parent': '10', 'count': 210, 'id': '62', 'children': True, 'sub_cats': {'364': {'label': 'Notas adhesivas y banderitas', 'level': '4', 'path': '1/2/10/62/364/', 'parent': '62', 'count': 78, 'id': '364'}, '363': {'label': 'Motas y Tizas', 'level': '4', 'path': '1/2/10/62/363/', 'parent': '62', 'count': 17, 'id': '363'}, '361': {'label': 'Engrapadores, sacagrapas y grapas', 'level': '4', 'path': '1/2/10/62/361/', 'parent': '62', 'count': 31, 'id': '361'}, '365': {'label': 'Perforadores', 'level': '4', 'path': '1/2/10/62/365/', 'parent': '62', 'count': 44, 'id': '365'}, '360': {'label': 'Calculadoras', 'level': '4', 'path': '1/2/10/62/360/', 'parent': '62', 'count': 37, 'id': '360'}, '362': {'label': 'Limpiatipos', 'level': '4', 'path': '1/2/10/62/362/', 'parent': '62', 'count': 3, 'id': '362'}}}, '59': {'label': 'Útiles', 'level': '3', 'path': '1/2/10/59/', 'parent': '10', 'count': 716, 'id': '59', 'children': True, 'sub_cats': {'342': {'label': 'Lapiceros', 'level': '4', 'path': '1/2/10/59/342/', 'parent': '59', 'count': 133, 'id': '342'}, '345': {'label': 'Plumones indelebles', 'level': '4', 'path': '1/2/10/59/345/', 'parent': '59', 'count': 14, 'id': '345'}, '348': {'label': 'Resaltadores', 'level': '4', 'path': '1/2/10/59/348/', 'parent': '59', 'count': 82, 'id': '348'}, '350': {'label': 'Tijeras', 'level': '4', 'path': '1/2/10/59/350/', 'parent': '59', 'count': 58, 'id': '350'}, '341': {'label': 'Correctores', 'level': '4', 'path': '1/2/10/59/341/', 'parent': '59', 'count': 17, 'id': '341'}, '340': {'label': 'Borradores', 'level': '4', 'path': '1/2/10/59/340/', 'parent': '59', 'count': 31, 'id': '340'}, '343': {'label': 'Lápices', 'level': '4', 'path': '1/2/10/59/343/', 'parent': '59', 'count': 65, 'id': '343'}, '349': {'label': 'Tajadores', 'level': '4', 'path': '1/2/10/59/349/', 'parent': '59', 'count': 35, 'id': '349'}, '346': {'label': 'Plumones para papel', 'level': '4', 'path': '1/2/10/59/346/', 'parent': '59', 'count': 287, 'id': '346'}, '344': {'label': 'Pizarras', 'level': '4', 'path': '1/2/10/59/344/', 'parent': '59', 'count': 7, 'id': '344'}}}, '58': {'label': 'Papelería', 'level': '3', 'path': '1/2/10/58/', 'parent': '10', 'count': 31, 'id': '58', 'children': True, 'sub_cats': {'337': {'label': 'Papel bond', 'level': '4', 'path': '1/2/10/58/337/', 'parent': '58', 'count': 25, 'id': '337'}, '338': {'label': 'Papel fotocopia', 'level': '4', 'path': '1/2/10/58/338/', 'parent': '58', 'count': 15, 'id': '338'}, '339': {'label': 'Papelógrafos', 'level': '4', 'path': '1/2/10/58/339/', 'parent': '58', 'count': 4, 'id': '339'}}}, '61': {'label': 'Cintas y Pegamentos', 'level': '3', 'path': '1/2/10/61/', 'parent': '10', 'count': 145, 'id': '61', 'children': True, 'sub_cats': {'357': {'label': 'Gomas, siliconas y colas', 'level': '4', 'path': '1/2/10/61/357/', 'parent': '61', 'count': 51, 'id': '357'}, '356': {'label': 'Cintas adhesivas y masking tape', 'level': '4', 'path': '1/2/10/61/356/', 'parent': '61', 'count': 65, 'id': '356'}, '359': {'label': 'Otros Pegamentos', 'level': '4', 'path': '1/2/10/61/359/', 'parent': '61', 'count': 27, 'id': '359'}, '358': {'label': 'Limpiatipos', 'level': '4', 'path': '1/2/10/61/358/', 'parent': '61', 'count': 3, 'id': '358'}}}, '56': {'label': 'Cuadernos y Blocks', 'level': '3', 'path': '1/2/10/56/', 'parent': '10', 'count': 194, 'id': '56', 'children': True, 'sub_cats': {'324': {'label': 'Block Manualidades', 'level': '4', 'path': '1/2/10/56/324/', 'parent': '56', 'count': 27, 'id': '324'}, '327': {'label': 'Cuadernos grapados A4', 'level': '4', 'path': '1/2/10/56/327/', 'parent': '56', 'count': 67, 'id': '327'}, '326': {'label': 'Cuadernos cosidos', 'level': '4', 'path': '1/2/10/56/326/', 'parent': '56', 'count': 12, 'id': '326'}, '323': {'label': 'Blocks de escritura y libretas', 'level': '4', 'path':  ...
# 10
# group > Universitario 10
# cats > Otros 62
# subcats > Notas adhesivas y banderitas 364 78
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Motas y Tizas 363 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Engrapadores, sacagrapas y grapas 361 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Perforadores 365 44
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Calculadoras 360 37
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpiatipos 362 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Útiles 59
# subcats > Lapiceros 342 133
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones indelebles 345 14
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Resaltadores 348 82
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tijeras 350 58
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Correctores 341 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Borradores 340 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lápices 343 65
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tajadores 349 35
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones para papel 346 287
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pizarras 344 7
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Papelería 58
# subcats > Papel bond 337 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel fotocopia 338 15
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papelógrafos 339 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cintas y Pegamentos 61
# subcats > Gomas, siliconas y colas 357 51
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cintas adhesivas y masking tape 356 65
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Otros Pegamentos 359 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpiatipos 358 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cuadernos y Blocks 56
# subcats > Block Manualidades 324 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos grapados A4 327 67
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos cosidos 326 12
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Blocks de escritura y libretas 323 36
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos anillados 325 29
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Sketchbooks 330 18
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos grapados A5 328 3
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Libretas 329 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cartucheras, Mochilas y Loncheras 60
# subcats > Maletas y mochilas 353 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tapers 354 20
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tomatodos 355 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cartucheras 351 15
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Loncheras 352 2
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Archivo 57
# subcats > Sobres de papel 336 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Portapapel y micas 334 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Carpetas y archivo 331 70
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pioners 333 56
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Files y folders de manila 332 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Separadores 335 8
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'11': {'label': 'Oficina', 'level': '2', 'path': '1/2/11/', 'count': 1495, 'id': '11', 'children': True, 'cats': {'63': {'label': 'Útiles', 'level': '3', 'path': '1/2/11/63/', 'parent': '11', 'count': 671, 'id': '63', 'children': True, 'sub_cats': {'369': {'label': 'Lapiceros', 'level': '4', 'path': '1/2/11/63/369/', 'parent': '63', 'count': 133, 'id': '369'}, '368': {'label': 'Correctores', 'level': '4', 'path': '1/2/11/63/368/', 'parent': '63', 'count': 17, 'id': '368'}, '375': {'label': 'Resaltadores', 'level': '4', 'path': '1/2/11/63/375/', 'parent': '63', 'count': 82, 'id': '375'}, '370': {'label': 'Lápices', 'level': '4', 'path': '1/2/11/63/370/', 'parent': '63', 'count': 65, 'id': '370'}, '376': {'label': 'Tajadores', 'level': '4', 'path': '1/2/11/63/376/', 'parent': '63', 'count': 35, 'id': '376'}, '374': {'label': 'Portaminas y minas', 'level': '4', 'path': '1/2/11/63/374/', 'parent': '63', 'count': 19, 'id': '374'}, '371': {'label': 'Plumones Indelebles', 'level': '4', 'path': '1/2/11/63/371/', 'parent': '63', 'count': 13, 'id': '371'}, '367': {'label': 'Borradores', 'level': '4', 'path': '1/2/11/63/367/', 'parent': '63', 'count': 31, 'id': '367'}, '372': {'label': 'Plumones para papel', 'level': '4', 'path': '1/2/11/63/372/', 'parent': '63', 'count': 287, 'id': '372'}}}, '68': {'label': 'Papelería', 'level': '3', 'path': '1/2/11/68/', 'parent': '11', 'count': 33, 'id': '68', 'children': True, 'sub_cats': {'390': {'label': 'Papel Bond', 'level': '4', 'path': '1/2/11/68/390/', 'parent': '68', 'count': 25, 'id': '390'}, '392': {'label': 'Papel Fotocopia', 'level': '4', 'path': '1/2/11/68/392/', 'parent': '68', 'count': 16, 'id': '392'}, '395': {'label': 'Papeles Finos', 'level': '4', 'path': '1/2/11/68/395/', 'parent': '68', 'count': 1, 'id': '395'}, '394': {'label': 'Papeles Adhesivos', 'level': '4', 'path': '1/2/11/68/394/', 'parent': '68', 'count': 2, 'id': '394'}, '393': {'label': 'Papel Periódico', 'level': '4', 'path': '1/2/11/68/393/', 'parent': '68', 'count': 1, 'id': '393'}, '396': {'label': 'Papelógrafos', 'level': '4', 'path': '1/2/11/68/396/', 'parent': '68', 'count': 4, 'id': '396'}}}, '64': {'label': 'Artículos de Escritorio', 'level': '3', 'path': '1/2/11/64/', 'parent': '11', 'count': 367, 'id': '64', 'children': True, 'sub_cats': {'386': {'label': 'Tijeras', 'level': '4', 'path': '1/2/11/64/386/', 'parent': '64', 'count': 58, 'id': '386'}, '382': {'label': 'Notas adhesivas y banderitas', 'level': '4', 'path': '1/2/11/64/382/', 'parent': '64', 'count': 78, 'id': '382'}, '385': {'label': 'Sellos y tampones', 'level': '4', 'path': '1/2/11/64/385/', 'parent': '64', 'count': 16, 'id': '385'}, '381': {'label': 'Engrapadores, sacagrapas y grapas', 'level': '4', 'path': '1/2/11/64/381/', 'parent': '64', 'count': 31, 'id': '381'}, '378': {'label': 'Clips, alfiler, chinches y ligas', 'level': '4', 'path': '1/2/11/64/378/', 'parent': '64', 'count': 41, 'id': '378'}, '380': {'label': 'Dispensadores', 'level': '4', 'path': '1/2/11/64/380/', 'parent': '64', 'count': 9, 'id': '380'}, '384': {'label': 'Perforadores', 'level': '4', 'path': '1/2/11/64/384/', 'parent': '64', 'count': 44, 'id': '384'}, '377': {'label': 'Bandejas y porta lapiceros', 'level': '4', 'path': '1/2/11/64/377/', 'parent': '64', 'count': 86, 'id': '377'}, '379': {'label': 'Cuchillas', 'level': '4', 'path': '1/2/11/64/379/', 'parent': '64', 'count': 4, 'id': '379'}}}, '66': {'label': 'Muebles de Oficina', 'level': '3', 'path': '1/2/11/66/', 'parent': '11', 'count': 16, 'id': '66', 'children': True, 'sub_cats': {'388': {'label': 'Sillas', 'level': '4', 'path': '1/2/11/66/388/', 'parent': '66', 'count': 16, 'id': '388'}}}, '72': {'label': 'Contabilidad y Administración', 'level': '3', 'path': '1/2/11/72/', 'parent': '11', 'count': 14, 'id': '72', 'children': True, 'sub_cats': {'415': {'label': 'Libros contables', 'level': '4', 'path': '1/2/11/72/415/', 'parent': '72', 'count': 4, 'id': '415'}, '417': {'label': 'Papeles y formatos contínuos', 'level' ...
# 11
# group > Oficina 11
# cats > Útiles 63
# subcats > Lapiceros 369 133
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Correctores 368 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Resaltadores 375 82
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lápices 370 65
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tajadores 376 35
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Portaminas y minas 374 19
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones Indelebles 371 13
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Borradores 367 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Plumones para papel 372 287
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Papelería 68
# subcats > Papel Bond 390 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Fotocopia 392 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles Finos 395 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles Adhesivos 394 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel Periódico 393 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papelógrafos 396 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Artículos de Escritorio 64
# subcats > Tijeras 386 58
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Notas adhesivas y banderitas 382 78
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Sellos y tampones 385 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Engrapadores, sacagrapas y grapas 381 31
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Clips, alfiler, chinches y ligas 378 41
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Dispensadores 380 9
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Perforadores 384 44
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Bandejas y porta lapiceros 377 86
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuchillas 379 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Muebles de Oficina 66
# subcats > Sillas 388 16
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Contabilidad y Administración 72
# subcats > Libros contables 415 4
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papeles y formatos contínuos 417 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel carbón 416 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuadernos empastados 414 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Embalaje, Cintas y Pegamentos 69
# subcats > Gomas siliconas y colas 400 51
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cintas de embalaje 399 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Otros Pegamentos 402 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Bolsas 397 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cintas adhesivas y masking tape 398 65
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpiatipos 401 3
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Stretch film 403 1
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Archivo 71
# subcats > Sobres de papel 413 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Separadores 412 8
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Files y folders de manila 409 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Carpetas y archivo 408 83
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Portapapel y micas 411 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pioners 410 56
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Archivadores de palanca 407 12
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Accesorios de Oficina 70
# subcats > Motas y Tizas 404 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pizarras 405 7
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'621': {'label': 'Cuidado Personal y Limpieza', 'level': '2', 'path': '1/2/621/', 'count': 171, 'id': '621', 'children': True, 'cats': {'622': {'label': 'Cuidado Personal', 'level': '3', 'path': '1/2/621/622/', 'parent': '621', 'count': 75, 'id': '622', 'children': True, 'sub_cats': {'638': {'label': 'Cuidado de la Salud', 'level': '4', 'path': '1/2/621/622/638/', 'parent': '622', 'count': 23, 'id': '638'}, '625': {'label': 'Cuidado del Bebé', 'level': '4', 'path': '1/2/621/622/625/', 'parent': '622', 'count': 18, 'id': '625'}, '628': {'label': 'Jabón Líquido', 'level': '4', 'path': '1/2/621/622/628/', 'parent': '622', 'count': 17, 'id': '628'}, '624': {'label': 'Cuidado Bucal', 'level': '4', 'path': '1/2/621/622/624/', 'parent': '622', 'count': 11, 'id': '624'}, '626': {'label': 'Jabón en Barra', 'level': '4', 'path': '1/2/621/622/626/', 'parent': '622', 'count': 9, 'id': '626'}}}, '623': {'label': 'Limpieza', 'level': '3', 'path': '1/2/621/623/', 'parent': '621', 'count': 97, 'id': '623', 'children': True, 'sub_cats': {'630': {'label': 'Limpieza de la Cocina', 'level': '4', 'path': '1/2/621/623/630/', 'parent': '623', 'count': 34, 'id': '630'}, '631': {'label': 'Limpieza del Hogar', 'level': '4', 'path': '1/2/621/623/631/', 'parent': '623', 'count': 50, 'id': '631'}, '632': {'label': 'Papel para el Hogar', 'level': '4', 'path': '1/2/621/623/632/', 'parent': '623', 'count': 6, 'id': '632'}, '629': {'label': 'Ambientadores', 'level': '4', 'path': '1/2/621/623/629/', 'parent': '623', 'count': 14, 'id': '629'}}}}}}
# 621
# group > Cuidado Personal y Limpieza 621
# cats > Cuidado Personal 622
# subcats > Cuidado de la Salud 638 23
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuidado del Bebé 625 18
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Jabón Líquido 628 17
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cuidado Bucal 624 11
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Jabón en Barra 626 9
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Limpieza 623
# subcats > Limpieza de la Cocina 630 34
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Limpieza del Hogar 631 50
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Papel para el Hogar 632 6
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Ambientadores 629 14
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'5': {'label': 'Tecnología', 'level': '2', 'path': '1/2/5/', 'count': 486, 'id': '5', 'children': True, 'cats': {'27': {'label': 'Fotografía', 'level': '3', 'path': '1/2/5/27/', 'parent': '5', 'count': 59, 'id': '27', 'children': True, 'sub_cats': {'142': {'label': 'Cámaras de Video', 'level': '4', 'path': '1/2/5/27/142/', 'parent': '27', 'count': 59, 'id': '142'}, '145': {'label': 'Drones', 'level': '4', 'path': '1/2/5/27/145/', 'parent': '27', 'count': 59, 'id': '145'}, '141': {'label': 'Cámaras Compactas', 'level': '4', 'path': '1/2/5/27/141/', 'parent': '27', 'count': 59, 'id': '141'}, '143': {'label': 'Cámaras instantáneas', 'level': '4', 'path': '1/2/5/27/143/', 'parent': '27', 'count': 59, 'id': '143'}, '144': {'label': 'Cámaras Profesionales', 'level': '4', 'path': '1/2/5/27/144/', 'parent': '27', 'count': 59, 'id': '144'}}}, '32': {'label': 'Electrohogar', 'level': '3', 'path': '1/2/5/32/', 'parent': '5', 'count': 4, 'id': '32', 'children': True, 'sub_cats': {'170': {'label': 'Electrodomésticos', 'level': '4', 'path': '1/2/5/32/170/', 'parent': '32', 'count': 4, 'id': '170'}}}, '33': {'label': 'Accesorios de Computo', 'level': '3', 'path': '1/2/5/33/', 'parent': '5', 'count': 133, 'id': '33', 'children': True, 'sub_cats': {'180': {'label': 'Otros accesorios', 'level': '4', 'path': '1/2/5/33/180/', 'parent': '33', 'count': 53, 'id': '180'}, '178': {'label': 'Mouse', 'level': '4', 'path': '1/2/5/33/178/', 'parent': '33', 'count': 42, 'id': '178'}, '175': {'label': 'Kit Teclados', 'level': '4', 'path': '1/2/5/33/175/', 'parent': '33', 'count': 9, 'id': '175'}, '181': {'label': 'Teclados', 'level': '4', 'path': '1/2/5/33/181/', 'parent': '33', 'count': 5, 'id': '181'}, '179': {'label': 'Mousepads', 'level': '4', 'path': '1/2/5/33/179/', 'parent': '33', 'count': 5, 'id': '179'}, '174': {'label': 'Discos duros y memorias', 'level': '4', 'path': '1/2/5/33/174/', 'parent': '33', 'count': 25, 'id': '174'}}}, '34': {'label': 'Otros', 'level': '3', 'path': '1/2/5/34/', 'parent': '5', 'count': 55, 'id': '34', 'children': True, 'sub_cats': {'182': {'label': 'Calculadoras Y Otros', 'level': '4', 'path': '1/2/5/34/182/', 'parent': '34', 'count': 41, 'id': '182'}, '183': {'label': 'Pilas, Baterías, Cargadores', 'level': '4', 'path': '1/2/5/34/183/', 'parent': '34', 'count': 14, 'id': '183'}}}, '28': {'label': 'Art Technology', 'level': '3', 'path': '1/2/5/28/', 'parent': '5', 'count': 19, 'id': '28', 'children': True, 'sub_cats': {'147': {'label': 'Accesorios de Arte', 'level': '4', 'path': '1/2/5/28/147/', 'parent': '28', 'count': 3, 'id': '147'}, '149': {'label': 'Tabletas Gráficas', 'level': '4', 'path': '1/2/5/28/149/', 'parent': '28', 'count': 7, 'id': '149'}, '148': {'label': 'Monitores Interactivos', 'level': '4', 'path': '1/2/5/28/148/', 'parent': '28', 'count': 5, 'id': '148'}, '604': {'label': 'Impresoras 3D', 'level': '4', 'path': '1/2/5/28/604/', 'parent': '28', 'count': 6, 'id': '604'}}}, '26': {'label': 'Audio', 'level': '3', 'path': '1/2/5/26/', 'parent': '5', 'count': 94, 'id': '26', 'children': True, 'sub_cats': {'136': {'label': 'Audífonos', 'level': '4', 'path': '1/2/5/26/136/', 'parent': '26', 'count': 83, 'id': '136'}, '139': {'label': 'Parlantes y Micrófonos', 'level': '4', 'path': '1/2/5/26/139/', 'parent': '26', 'count': 11, 'id': '139'}}}, '31': {'label': 'Celulares', 'level': '3', 'path': '1/2/5/31/', 'parent': '5', 'count': 88, 'id': '31', 'children': True, 'sub_cats': {'163': {'label': 'Audífonos', 'level': '4', 'path': '1/2/5/31/163/', 'parent': '31', 'count': 83, 'id': '163'}, '165': {'label': 'Cargadores y Cables', 'level': '4', 'path': '1/2/5/31/165/', 'parent': '31', 'count': 5, 'id': '165'}}}, '25': {'label': 'Tv y Video', 'level': '3', 'path': '1/2/5/25/', 'parent': '5', 'count': 3, 'id': '25', 'children': True, 'sub_cats': {'134': {'label': 'Soundbar y Home Theater', 'level': '4', 'path': '1/2/5/25/134/', 'parent': '25', 'count': 2, 'id': '134'}, '135': {'label': 'Televisores', 'level': '4', 'path ...
# 5
# group > Tecnología 5
# cats > Fotografía 27
# subcats > Cámaras de Video 142 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Drones 145 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras Compactas 141 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras instantáneas 143 59
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cámaras Profesionales 144 59
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Electrohogar 32
# subcats > Electrodomésticos 170 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Accesorios de Computo 33
# subcats > Otros accesorios 180 53
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Mouse 178 42
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Kit Teclados 175 9
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Teclados 181 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Mousepads 179 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Discos duros y memorias 174 25
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Otros 34
# subcats > Calculadoras Y Otros 182 41
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pilas, Baterías, Cargadores 183 14
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Art Technology 28
# subcats > Accesorios de Arte 147 3
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tabletas Gráficas 149 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Monitores Interactivos 148 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Impresoras 3D 604 6
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Audio 26
# subcats > Audífonos 136 83
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Parlantes y Micrófonos 139 11
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Celulares 31
# subcats > Audífonos 163 83
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Cargadores y Cables 165 5
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Tv y Video 25
# subcats > Soundbar y Home Theater 134 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Televisores 135 1
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Computo 30
# subcats > Componentes de PC 156 37
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Monitores 160 6
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Discos Duros y Memoria 157 25
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Láptops y Tablets 159 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Impresoras 158 5
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Tintas y Tóners 161 77
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Mundo Gamer 29
# subcats > Sillas Gamer 154 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Accesorios Gamer 150 2
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > PC Gamer 153 6
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Consolas 152 36
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'6': {'label': 'Zona Coleccionista', 'level': '2', 'path': '1/2/6/', 'count': 404, 'id': '6', 'children': True, 'cats': {'35': {'label': 'Figuras', 'level': '3', 'path': '1/2/6/35/', 'parent': '6', 'count': 404, 'id': '35', 'children': True, 'sub_cats': {'184': {'label': 'Banpresto', 'level': '4', 'path': '1/2/6/35/184/', 'parent': '35', 'count': 404, 'id': '184'}, '185': {'label': 'Funko', 'level': '4', 'path': '1/2/6/35/185/', 'parent': '35', 'count': 404, 'id': '185'}, '186': {'label': 'Mezco', 'level': '4', 'path': '1/2/6/35/186/', 'parent': '35', 'count': 404, 'id': '186'}, '187': {'label': 'Neca', 'level': '4', 'path': '1/2/6/35/187/', 'parent': '35', 'count': 404, 'id': '187'}}}}}}
# 6
# group > Zona Coleccionista 6
# cats > Figuras 35
# subcats > Banpresto 184 404
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Funko 185 404
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Mezco 186 404
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Neca 187 404
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'7': {'label': 'Outdoors & Deporte', 'level': '2', 'path': '1/2/7/', 'count': 98, 'id': '7', 'children': True, 'cats': {'39': {'label': 'Máquinas', 'level': '3', 'path': '1/2/7/39/', 'parent': '7', 'count': 7, 'id': '39', 'children': True, 'sub_cats': {'195': {'label': 'Home Gym', 'level': '4', 'path': '1/2/7/39/195/', 'parent': '39', 'count': 7, 'id': '195'}, '196': {'label': 'Spinning', 'level': '4', 'path': '1/2/7/39/196/', 'parent': '39', 'count': 7, 'id': '196'}, '197': {'label': 'Trotadora', 'level': '4', 'path': '1/2/7/39/197/', 'parent': '39', 'count': 7, 'id': '197'}, '194': {'label': 'Elípticas', 'level': '4', 'path': '1/2/7/39/194/', 'parent': '39', 'count': 7, 'id': '194'}}}, '40': {'label': 'Movilidad Eléctrica', 'level': '3', 'path': '1/2/7/40/', 'parent': '7', 'count': 9, 'id': '40', 'children': True, 'sub_cats': {'198': {'label': 'Accesorios', 'level': '4', 'path': '1/2/7/40/198/', 'parent': '40', 'count': 1, 'id': '198'}, '200': {'label': 'Scooter Eléctrico', 'level': '4', 'path': '1/2/7/40/200/', 'parent': '40', 'count': 4, 'id': '200'}, '199': {'label': 'Bicicleta Eléctrica', 'level': '4', 'path': '1/2/7/40/199/', 'parent': '40', 'count': 4, 'id': '199'}}}, '41': {'label': 'Juegos de Exterior', 'level': '3', 'path': '1/2/7/41/', 'parent': '7', 'count': 80, 'id': '41', 'children': True, 'sub_cats': {'203': {'label': 'Camas Elásticas', 'level': '4', 'path': '1/2/7/41/203/', 'parent': '41', 'count': 1, 'id': '203'}, '211': {'label': 'Scooters', 'level': '4', 'path': '1/2/7/41/211/', 'parent': '41', 'count': 28, 'id': '211'}, '208': {'label': 'Patines', 'level': '4', 'path': '1/2/7/41/208/', 'parent': '41', 'count': 1, 'id': '208'}, '210': {'label': 'Piscinas Inflables', 'level': '4', 'path': '1/2/7/41/210/', 'parent': '41', 'count': 1, 'id': '210'}, '204': {'label': 'Casa de Juegos', 'level': '4', 'path': '1/2/7/41/204/', 'parent': '41', 'count': 1, 'id': '204'}, '209': {'label': 'Pelotas', 'level': '4', 'path': '1/2/7/41/209/', 'parent': '41', 'count': 16, 'id': '209'}, '207': {'label': 'Juguetes Playa', 'level': '4', 'path': '1/2/7/41/207/', 'parent': '41', 'count': 35, 'id': '207'}, '206': {'label': 'Juegos Inflables', 'level': '4', 'path': '1/2/7/41/206/', 'parent': '41', 'count': 1, 'id': '206'}}}, '38': {'label': 'Bicicletas y Triciclos', 'level': '3', 'path': '1/2/7/38/', 'parent': '7', 'count': 11, 'id': '38', 'children': True, 'sub_cats': {'191': {'label': 'Bicicletas Montañeras', 'level': '4', 'path': '1/2/7/38/191/', 'parent': '38', 'count': 9, 'id': '191'}, '192': {'label': 'Bicicletas Urbanas', 'level': '4', 'path': '1/2/7/38/192/', 'parent': '38', 'count': 9, 'id': '192'}}}}}}
# 7
# group > Outdoors & Deporte 7
# cats > Máquinas 39
# subcats > Home Gym 195 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Spinning 196 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Trotadora 197 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Elípticas 194 7
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Movilidad Eléctrica 40
# subcats > Accesorios 198 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Scooter Eléctrico 200 4
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Bicicleta Eléctrica 199 4
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juegos de Exterior 41
# subcats > Camas Elásticas 203 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Scooters 211 28
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Patines 208 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Piscinas Inflables 210 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Casa de Juegos 204 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pelotas 209 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juguetes Playa 207 35
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juegos Inflables 206 1
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Bicicletas y Triciclos 38
# subcats > Bicicletas Montañeras 191 9
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Bicicletas Urbanas 192 9
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'16': {'label': 'Fisher Price', 'level': '2', 'path': '1/2/16/', 'count': 162, 'id': '16', 'children': True, 'cats': {'612': {'label': 'Gimnasios', 'level': '3', 'path': '1/2/16/612/', 'parent': '16', 'count': 8, 'id': '612'}, '613': {'label': 'Juguetes', 'level': '3', 'path': '1/2/16/613/', 'parent': '16', 'count': 107, 'id': '613'}, '616': {'label': 'Móviles para Bebés', 'level': '3', 'path': '1/2/16/616/', 'parent': '16', 'count': 3, 'id': '616'}, '610': {'label': 'Cuidado del Bebé', 'level': '3', 'path': '1/2/16/610/', 'parent': '16', 'count': 7, 'id': '610'}, '619': {'label': 'Sonajas', 'level': '3', 'path': '1/2/16/619/', 'parent': '16', 'count': 6, 'id': '619'}, '614': {'label': 'Mecedoras', 'level': '3', 'path': '1/2/16/614/', 'parent': '16', 'count': 4, 'id': '614'}, '611': {'label': 'Exteriores', 'level': '3', 'path': '1/2/16/611/', 'parent': '16', 'count': 14, 'id': '611'}, '618': {'label': 'Sillas de Comer', 'level': '3', 'path': '1/2/16/618/', 'parent': '16', 'count': 2, 'id': '618'}, '617': {'label': 'Sillas de Auto', 'level': '3', 'path': '1/2/16/617/', 'parent': '16', 'count': 11, 'id': '617'}}}}
# 16
# group > Fisher Price 16
# cats > Gimnasios 612
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juguetes 613
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Móviles para Bebés 616
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Cuidado del Bebé 610
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Sonajas 619
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Mecedoras 614
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Exteriores 611
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Sillas de Comer 618
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Sillas de Auto 617
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'3': {'label': 'Juguetería', 'level': '2', 'path': '1/2/3/', 'count': 1050, 'id': '3', 'children': True, 'cats': {'21': {'label': 'Juguetes', 'level': '3', 'path': '1/2/3/21/', 'parent': '3', 'count': 492, 'id': '21', 'children': True, 'sub_cats': {'109': {'label': 'Otros Juguetes', 'level': '4', 'path': '1/2/3/21/109/', 'parent': '21', 'count': 90, 'id': '109'}, '106': {'label': 'Mascotas', 'level': '4', 'path': '1/2/3/21/106/', 'parent': '21', 'count': 36, 'id': '106'}, '105': {'label': 'Lanzadores', 'level': '4', 'path': '1/2/3/21/105/', 'parent': '21', 'count': 24, 'id': '105'}, '114': {'label': 'Pelotas', 'level': '4', 'path': '1/2/3/21/114/', 'parent': '21', 'count': 16, 'id': '114'}, '116': {'label': 'Vehículos y Pistas', 'level': '4', 'path': '1/2/3/21/116/', 'parent': '21', 'count': 90, 'id': '116'}, '107': {'label': 'Muñecas Bebé', 'level': '4', 'path': '1/2/3/21/107/', 'parent': '21', 'count': 166, 'id': '107'}, '110': {'label': 'Peluches', 'level': '4', 'path': '1/2/3/21/110/', 'parent': '21', 'count': 1, 'id': '110'}, '103': {'label': 'Juegos de Rol', 'level': '4', 'path': '1/2/3/21/103/', 'parent': '21', 'count': 70, 'id': '103'}}}, '18': {'label': 'Juegos de Exterior', 'level': '3', 'path': '1/2/3/18/', 'parent': '3', 'count': 90, 'id': '18', 'children': True, 'sub_cats': {'90': {'label': 'Bicicletas y Triciclos Niños', 'level': '4', 'path': '1/2/3/18/90/', 'parent': '18', 'count': 11, 'id': '90'}, '120': {'label': 'Patines', 'level': '4', 'path': '1/2/3/18/120/', 'parent': '18', 'count': 1, 'id': '120'}, '93': {'label': 'Pelotas', 'level': '4', 'path': '1/2/3/18/93/', 'parent': '18', 'count': 16, 'id': '93'}, '94': {'label': 'Scooters', 'level': '4', 'path': '1/2/3/18/94/', 'parent': '18', 'count': 28, 'id': '94'}, '92': {'label': 'Juguetes Playa', 'level': '4', 'path': '1/2/3/18/92/', 'parent': '18', 'count': 35, 'id': '92'}}}, '19': {'label': 'Juegos de Mesa', 'level': '3', 'path': '1/2/3/19/', 'parent': '3', 'count': 167, 'id': '19', 'children': True, 'sub_cats': {'95': {'label': 'Juegos de Mesa', 'level': '4', 'path': '1/2/3/19/95/', 'parent': '19', 'count': 145, 'id': '95'}, '96': {'label': 'Rompecabezas', 'level': '4', 'path': '1/2/3/19/96/', 'parent': '19', 'count': 29, 'id': '96'}}}, '20': {'label': 'Juguetes Educativos', 'level': '3', 'path': '1/2/3/20/', 'parent': '3', 'count': 130, 'id': '20', 'children': True, 'sub_cats': {'101': {'label': 'Rompecabezas Didácticos', 'level': '4', 'path': '1/2/3/20/101/', 'parent': '20', 'count': 7, 'id': '101'}, '99': {'label': 'Juegos Educativos', 'level': '4', 'path': '1/2/3/20/99/', 'parent': '20', 'count': 13, 'id': '99'}, '97': {'label': 'Art & Crafts', 'level': '4', 'path': '1/2/3/20/97/', 'parent': '20', 'count': 27, 'id': '97'}, '100': {'label': 'Play Doh', 'level': '4', 'path': '1/2/3/20/100/', 'parent': '20', 'count': 27, 'id': '100'}, '98': {'label': 'Bloques', 'level': '4', 'path': '1/2/3/20/98/', 'parent': '20', 'count': 56, 'id': '98'}}}, '17': {'label': 'Juguetes Bebés y Prescolar', 'level': '3', 'path': '1/2/3/17/', 'parent': '3', 'count': 233, 'id': '17', 'children': True, 'sub_cats': {'88': {'label': 'Prescolar', 'level': '4', 'path': '1/2/3/17/88/', 'parent': '17', 'count': 86, 'id': '88'}, '89': {'label': 'Primera Edad', 'level': '4', 'path': '1/2/3/17/89/', 'parent': '17', 'count': 147, 'id': '89'}}}, '637': {'label': 'Mattel', 'level': '3', 'path': '1/2/3/637/', 'parent': '3', 'count': 38, 'id': '637'}}}}
# 3
# group > Juguetería 3
# cats > Juguetes 21
# subcats > Otros Juguetes 109 90
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Mascotas 106 36
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Lanzadores 105 24
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pelotas 114 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Vehículos y Pistas 116 90
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Muñecas Bebé 107 166
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Peluches 110 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juegos de Rol 103 70
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juegos de Exterior 18
# subcats > Bicicletas y Triciclos Niños 90 11
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Patines 120 1
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Pelotas 93 16
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Scooters 94 28
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juguetes Playa 92 35
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juegos de Mesa 19
# subcats > Juegos de Mesa 95 145
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Rompecabezas 96 29
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juguetes Educativos 20
# subcats > Rompecabezas Didácticos 101 7
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Juegos Educativos 99 13
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Art & Crafts 97 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Play Doh 100 27
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Bloques 98 56
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Juguetes Bebés y Prescolar 17
# subcats > Prescolar 88 86
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Primera Edad 89 147
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Mattel 637
# url post > https://www.tailoy.com.pe/elastic.php
# url post > https://www.tailoy.com.pe/elastic.php
# {'639': {'label': 'Abarrotes', 'level': '2', 'path': '1/2/639/', 'count': 15, 'id': '639', 'children': True, 'cats': {'640': {'label': 'Aguas y Bebidas', 'level': '3', 'path': '1/2/639/640/', 'parent': '639', 'count': 3, 'id': '640', 'children': True, 'sub_cats': {'643': {'label': 'Aguas y Otras Bebidas', 'level': '4', 'path': '1/2/639/640/643/', 'parent': '640', 'count': 3, 'id': '643'}}}, '641': {'label': 'Abarrotes No Comestibles', 'level': '3', 'path': '1/2/639/641/', 'parent': '639', 'count': 12, 'id': '641', 'children': True, 'sub_cats': {'642': {'label': 'Bolsas para alimentos', 'level': '4', 'path': '1/2/639/641/642/', 'parent': '641', 'count': 3, 'id': '642'}, '645': {'label': 'Otros', 'level': '4', 'path': '1/2/639/641/645/', 'parent': '641', 'count': 4, 'id': '645'}}}}}}
# 639
# group > Abarrotes 639
# cats > Aguas y Bebidas 640
# subcats > Aguas y Otras Bebidas 643 3
# url post > https://www.tailoy.com.pe/elastic.php
# cats > Abarrotes No Comestibles 641
# subcats > Bolsas para alimentos 642 3
# url post > https://www.tailoy.com.pe/elastic.php
# subcats > Otros 645 4
# url post > https://www.tailoy.com.pe/elastic.php

# %%
[{
    'id_group':'45',
    'name_group': 'Escolar'
    'cats':[{
        'id_cat' : '56',
        'name_cat': 'Archivos',
        'sub_cat':[{
            'id_subcat':'65456',
            'name_subcat': 'Carpetas y Portatodos'
            
        },{
            'id_subcat':'65456',
            'name_subcat': 'Papeleria'
            
        },{
            'id_subcat':'65456',
            'name_subcat': 'xxx'
            
        }]
    },{
        'id' : '56',
        'name': 'Archivos',
        'sub_sub_cat':{
            
        }
    }]
},{
    'id':'45',
    'name': 'Tecnologia'
    'sub_cat':[{
        'id' : '56',
        'name': 'Archivos',
        'sub_sub_cat':{
            
        }
    },{
        'id' : '56',
        'name': 'Archivos',
        'sub_sub_cat':{
            
        }
    }]
},]
